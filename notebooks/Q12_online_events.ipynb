# %% [markdown]
# ## Q12 online events

# %%
# %load_ext quak
# pip install qucak #widget for table overview

# %%
import textwrap
import utils
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("../data/survey2024_headerscleaned.csv")

# %%
df.head()
# Out:
#       Timestamp What is your gender What is your age group  \
# 0  2/7/24 15:02                Male                  30-39
# 1  2/7/24 16:44              Female                  20-29
# 2  2/7/24 17:32   Prefer not to say               above 50
# 3  2/7/24 20:31              Female                  20-29
# 4  2/7/24 20:33                Male                  30-39
#
#   Which of these describe your position Choose all options that apply  \
# 0                 staff scientist in a core facility
# 1                                        PhD student
# 2                                          professor
# 3                                        PhD student
# 4                            postdoctoral researcher
#
#   Are you currently in a permanent position  \
# 0                                       Yes
# 1                                        No
# 2                                        No
# 3                                        No
# ...

# %%
loc_Q12=df[["Q12 If GloBIAS offers regular online events, how often would you ideally want them to happen"]]

# %%
loc_Q12["Q12 If GloBIAS offers regular online events, how often would you ideally want them to happen"].unique()
# Out:
# array(['Every three months', 'Monthly', 'Every six months', nan],
#       dtype=object)

# %%
loc_Q12.value_counts()
# Out:
# Q12 If GloBIAS offers regular online events, how often would you ideally want them to happen
# Every three months                                                                              171
# Monthly                                                                                          83
# Every six months                                                                                 32
# Name: count, dtype: int64

# %%
loc_Q12.describe()
# Out:
#        Q12 If GloBIAS offers regular online events, how often would you ideally want them to happen
# count                                                 286
# unique                                                  3
# top                                    Every three months
# freq                                                  171

# %%
utils.select_all_that_apply_hist_facet(df=df,
                                       question_col='Q12 If GloBIAS offers regular online events, how often would you ideally want them to happen',
                                       plot_filename='../figures/RegularOnlineEventsFrequency')
