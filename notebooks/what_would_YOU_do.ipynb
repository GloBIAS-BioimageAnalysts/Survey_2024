# %%
import pandas
import utils

df = pandas.read_csv("../data/survey2024_headersandcommascleaned.csv")

# %%
utils.select_all_that_apply_hist_facet(df=df,
                                       question_col='Q17 Would you be interested in joining a working group of the society after its foundation for any of the following areas',
                                       plot_filename='../figures/WhichWorkingGroup')
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/lib/python3.10/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
utils.select_all_that_apply_hist_facet(df=df,
                                       question_col='Q18 What other aspects beside the opportunities listed above would make you most likely to contribute to GloBIAS',
                                       plot_filename='../figures/WhatWouldMakeYouContribute')
