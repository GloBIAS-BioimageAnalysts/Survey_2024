# %%
import pandas
import utils

df = pandas.read_csv("../data/survey2024_headersandcommascleaned.csv")

# %%
utils.select_all_that_apply_hist_facet(df,
                                       'In which of these sectors do you work',
                                       '../figures/Sectors',)

# %%
utils.select_all_that_apply_hist_facet(df,
                                       'Q2 Which of the following do you work in Choose all options that apply',
                                       '../figures/Sectors_Q2',aspect=2)
