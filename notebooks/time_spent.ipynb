# %%
import pandas

import utils

df = pandas.read_csv('../data/survey2024_headerscleaned.csv')

# %%
short_colnames = {'bioimage analysis instruction':'instruction',
                  'bioimage analysis service':'service',
                  'bioimage analysis infrastructure development and maintenance':'infrastructure',
                  'own bioimage analysis project':'own\nprojects',
                  'bioimage analysis tool development not bound to a single service project':'tool\ndevelopment',
                  'management or administration':'management/\nadministration'}
long_colnames = {f'Q7 How much of your time do you spend on each of the following  [{k}]':v for k,v in short_colnames.items()}

utils.normalized_percent_graphs(df,long_colnames,'../figures/WhereTimeSpent_filtered.png',prints=True,xlabel = 'Time Spent')
# Out:
# Original shape: (291, 54)
# Shape after filtering: (271, 54)
# (236, 54) Q7 How much of your time do you spend on each of the following  [bioimage analysis instruction]
# 0-25%      174
# 0 %         28
# 25-50%      24
# 50-75%       7
# 75-100%      3
# Name: count, dtype: int64
# (208, 54) Q7 How much of your time do you spend on each of the following  [bioimage analysis service]
# 0-25%      94
# 0 %        57
# 25-50%     38
# 50-75%     15
# 75-100%     4
# Name: count, dtype: int64
# (185, 54) Q7 How much of your time do you spend on each of the following  [bioimage analysis infrastructure development and maintenance]
# 0-25%     92
# 0 %       70
# 25-50%    22
# 50-75%     1
# Name: count, dtype: int64
# (204, 54) Q7 How much of your time do you spend on each of the following  [own bioimage analysis project]
# 0-25%      81
# 25-50%     50
# 0 %        45
# 50-75%     19
# 75-100%     9
# Name: count, dtype: int64
# ...

# %%
utils.normalized_percent_graphs(df,long_colnames,'../figures/WhereTimeSpent_all.png',prints=True,include_null=True,xlabel = 'Time Spent')
# Out:
# Original shape: (291, 54)
# Shape after filtering: (271, 54)
# (271, 54) Q7 How much of your time do you spend on each of the following  [bioimage analysis instruction]
# 0-25%      174
#             35
# 0 %         28
# 25-50%      24
# 50-75%       7
# 75-100%      3
# Name: count, dtype: int64
# (271, 54) Q7 How much of your time do you spend on each of the following  [bioimage analysis service]
# 0-25%      94
#            63
# 0 %        57
# 25-50%     38
# 50-75%     15
# 75-100%     4
# Name: count, dtype: int64
# (271, 54) Q7 How much of your time do you spend on each of the following  [bioimage analysis infrastructure development and maintenance]
# 0-25%     92
#           86
# 0 %       70
# 25-50%    22
# 50-75%     1
# Name: count, dtype: int64
# (271, 54) Q7 How much of your time do you spend on each of the following  [own bioimage analysis project]
# 0-25%      81
#            67
# 25-50%     50
# 0 %        45
# 50-75%     19
# 75-100%     9
# ...
