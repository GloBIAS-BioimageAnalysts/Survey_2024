# %%
import pandas
import utils

df = pandas.read_csv("../data/survey2024_headerscleaned.csv")

# %%
options_dict = {
    "Life sciences research (planning, executing and analysing a range of experiments)": "Life sciences research (planning, executing\nand analysing a range of experiments)",
    "Imaging (sample preparation optimisation, acquiring images and data)": "Imaging (sample preparation optimisation,\nacquiring images and data)",
    "Imaging support (guidelines and tips for sample preparation optimisation, deciding on imaging modalities, help with acquisition of images and data)":"Imaging support (guidelines and tips for\n sample preparation optimisation, deciding\non imaging modalities, help with acquisition\nof images and data)",
    "Image analysis (finding the right tools to analyse a particular experiment, optimizing the analysis, data mining)":"Image analysis (finding the right tools\nto analyse a particular experiment,\noptimizing the analysis, data mining)",
    "Software engineering and/or method development (building tools, implementing state-of-the-art computer vision/ML-research)":"Software engineering and/or method development\n(building tools, implementing state-of-the-art\ncomputer vision/ML-research)",
    "Microscope development (building microscope and add-ons to microscope, development of software tools for control and data analysis for self-built systems)":"Microscope development (building microscopes and\nadd-ons to microscopes, development of software tools\nfor control and data analysis for self-built systems)",
}

# %%
utils.select_all_that_apply_hist_facet(df,
                                       'Q1 How would you describe your work  Choose all options that apply',
                                       '../figures/DescribeYourWork_byage',
                                       options_dict=options_dict,
                                       facet_col="What is your age group",
                                       delim="), ",aspect=2, how='color', palette='viridis')

# %%
utils.select_all_that_apply_hist_facet(df,
                                       'Q1 How would you describe your work  Choose all options that apply',
                                       '../figures/DescribeYourWork_bylocation',
                                       options_dict=options_dict,
                                       facet_col="What is your location",
                                       delim="), ",how='color',aspect=2)

# %%
utils.select_all_that_apply_hist_facet(df,
                                       'Q1 How would you describe your work  Choose all options that apply',
                                       '../figures/DescribeYourWork_bygender',
                                       options_dict=options_dict,
                                       facet_col="What is your gender",
                                       delim="), ",how='color',aspect=2)
