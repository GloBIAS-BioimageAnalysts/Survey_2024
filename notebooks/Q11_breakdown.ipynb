# %% [markdown]
# # Q11 breakdown

# %%
# %load_ext quak
# pip install qucak #widget for table overview

# %%
import textwrap

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("../data/survey2024_headerscleaned.csv")

# %%
df.head()
# Out:
#       Timestamp What is your gender What is your age group  \
# 0  2/7/24 15:02                Male                  30-39
# 1  2/7/24 16:44              Female                  20-29
# 2  2/7/24 17:32   Prefer not to say               above 50
# 3  2/7/24 20:31              Female                  20-29
# 4  2/7/24 20:33                Male                  30-39
#
#   Which of these describe your position Choose all options that apply  \
# 0                 staff scientist in a core facility
# 1                                        PhD student
# 2                                          professor
# 3                                        PhD student
# 4                            postdoctoral researcher
#
#   Are you currently in a permanent position  \
# 0                                       Yes
# 1                                        No
# 2                                        No
# 3                                        No
# ...

# %%
loc_Q11=df[["What is your location","Q11 Is there a specific type of event not listed in Q10 you would want to see organised by GloBIAS in its first year or thereafter"]]

# %%
loc_Q11["What is your location"].unique()
# Out:
# array(['Europe', 'South America', 'North America', 'Africa', 'Asia',
#        'Australia/ Oceania', 'Near/ Middle East', 'Central America', nan],
#       dtype=object)

# %%
loc_Q11.head()
# Out:
#   What is your location  \
# 0                Europe
# 1                Europe
# 2         South America
# 3                Europe
# 4                Europe
#
#   Q11 Is there a specific type of event not listed in Q10 you would want to see organised by GloBIAS in its first year or thereafter
# 0                                                NaN
# 1                                                NaN
# 2               Quality control and fraud prevention
# 3                                                NaN
# 4                                                NaN

# %%
loc_Q11_clean = loc_Q11.dropna(subset=["Q11 Is there a specific type of event not listed in Q10 you would want to see organised by GloBIAS in its first year or thereafter"])

# Group by unique values in 'Column1' and get the corresponding texts from 'Column2'
grouped = loc_Q11_clean.groupby("What is your location")["Q11 Is there a specific type of event not listed in Q10 you would want to see organised by GloBIAS in its first year or thereafter"].apply(lambda x: ';'.join(x)).reset_index()

# Export to CSV (or any other format you prefer)
# grouped.to_csv('Q11_based_on_location.csv', index=False)

# Display the result

grouped
# Out:
#   What is your location  \
# 0                Africa
# 1                  Asia
# 2    Australia/ Oceania
# 3                Europe
# 4         North America
# 5         South America
#
#   Q11 Is there a specific type of event not listed in Q10 you would want to see organised by GloBIAS in its first year or thereafter
# 0  Contribute in collaborative research between m...
# 1  Basic Image Analysis tasks and algorithms usin...
# 2  Developing tools or plugins such as in python,...
# 3  A hackaton/workshop on how to deploy workflows...
# 4  No;Hands-on training schools teaching basic an...
# 5  Quality control and fraud prevention;No;Financ...

# %% [markdown]
# ### Overlaps
# 1. **Workshops and Training**:
#    - **Africa, Europe, North America, South America**: All regions express a desire for workshops and training sessions, whether in-person or online.
#    - **Europe, North America**: Both regions specifically mention workshops on new bioimage analysis software tools.
#
# 2. **Conferences and Symposiums**:
#    - **Europe, North America**: Both regions are interested in conferences, with Europe specifically mentioning NEUBIAS-style conferences and North America mentioning a GloBIAS conference.
#
# 3. **Online Resources**:
#    - **Australia/Oceania, North America**: Both regions emphasize the importance of online symposiums and workshops.
#
# 4. **Data Management**:
#    - **Australia/Oceania, North America**: Both regions highlight the need for discussions on data management and practices.
#
# ### Differences
# 1. **Collaborative Research**:
#    - **Africa**: Emphasizes collaborative research and information dissemination about bioimaging equipment.
#
# 2. **Tool Development**:
#    - **Australia/Oceania**: Focuses on developing tools or plugins in Python and Fiji.
#
# 3. **Hackathons and Machine Learning**:
#    - **Europe**: Interested in hackathons/workshops on deploying workflows using machine learning or big data.
#
# 4. **Career Development**:
#    - **Europe, North America**: Europe mentions bioimage analyst career development, while North America focuses on hands-on training and career paths.
#
# 5. **Quality Control and Fraud Prevention**:
#    - **South America**: Specifically mentions quality control and fraud prevention, which is not highlighted by other regions.
#
# 6. **Financial Support**:
#    - **South America**: Emphasizes the need for financial support and finding funding sources for bioimaging projects.
#
# ### Summary
# - **Common Interests**: Workshops, conferences, online resources, and data management are common interests across multiple regions.
# - **Unique Needs**: Collaborative research (Africa), tool development (Australia/Oceania), hackathons (Europe), career development (Europe and North America), quality control (South America), and financial support (South America) are unique needs highlighted by specific regions.
